# %%
42

# %% [markdown]
# 43 - 1

# %%
42

# %%
6*7

# %%
42

# %%
def fondos ():
    saldo = 0
    meta = 1000
    while saldo < meta:
        deposito = int(input("Ingrese el deposito: "))
        saldo += deposito
    return saldo

resultado = fondos()
print("Meta superada $", resultado)
# Out:
# Ingrese el deposito:  43
# Ingrese el deposito:  567
# Ingrese el deposito:  567
# Meta superada $ 1177
